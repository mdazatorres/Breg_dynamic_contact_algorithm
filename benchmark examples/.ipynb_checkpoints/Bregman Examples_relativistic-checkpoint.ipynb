# %% [markdown]
# # Numerical results

# %%
import numpy as np
import matplotlib.pyplot as plt
import examples as exa
import scipy.integrate as si
from plot_ex import plot_order, plot_contourn
from integrators import HBr
plt.rcParams['font.size'] = 15

# %% [markdown]
# Method                          | Abbreviation|X0    |P0        |X0t    |P0t
# --------                        | -------     |-----|-----     |----- |-----
# Euclidean Bregman Bravetti      | EB          |0    | gradh(P0)|   -  | -
# Euclidean Bregman python        | odeintE     |0    | gradh(P0)| -    |-
# Relativistic Bregman Bravetti   | RB          |0    | gradh(P0)|  -   |-
# Relativistic Bregman python Hbr | odeint_R_Hbr|0    | 0        |   -  |-
# Relativistic Bregman python Kbr | odeint_R_Kbr|0    | gradh(P0)|    - |-
# Direct HTVI                     | HTVI_d      |0    | 0        |(0,1) |-Hbr(X0,P0,X0t)
# Adaptative HTVI                 | HTVI_adap   |0    | 0        |(0,1) |-Hbr(X0,P0,X0t)
# Direct Splitting (Betancourt)   | BS_d        |0    | 0        |    - |0

# %% [markdown]
# ## Example 1 (Quartic function)
#
# Let us start with a quartic function
#
# \begin{equation}\label{eq:quart}
# f(X)=[(X-1)^T \Sigma (X-1)]^2\in \mathbb{R}^{50},\quad \Sigma_{ij}=0.9^{|i-j|}.
# \end{equation}
# This convex function achieves its minimum value $0$ at $x^*=1$.

# %%
n = 2 # dimension
ex = exa.Example6(n)
plot_contourn(ex, xmin=-10, xmax=10, ymin=-10, ymax=10)

# %%
## Parameters
dt = 1e-4
c = 2   # order
C = 1
steps =10000

# %%
# Initial conditions 
p0 = np.zeros(n)  # p0=(0,0,...,0)
#p0 = np.random.rand(n)
x0 = np.random.rand(n)
#x0=np.ones(n)
#x0 = np.zeros(n)  # x0=(0,0,...,0)
x0_t = 0.01
p0_t = -HBr(ex, x0, p0, x0_t, c) #np.zeros(q0.shape)
init =[x0, x0_t, p0, p0_t] 
x0
# Out:
# array([0.68149866, 0.06915927])

# %%
## Euclidean Case
plt.figure(figsize=(10, 4))
plot_order('EB', color='c', marker='d', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex, init=init)
plot_order('odeintE', color='m', marker='h', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex, init=init)
plot_order('HTVI_d', color='r', marker='<', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex, init=init)
plot_order('HTVI_adap', color='y', marker='H', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex, init=init)
plot_order('BS_d', color='b', marker='<', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex, init=init)

# %%
## Relativistic Case
plt.figure(figsize=(10, 4))
plot_order('RB', color='k', marker='o', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('RB_adap', color='green', marker='x', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('RB_adap_new', color='r', marker='x', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('odeint_R_Kbr', color='y', marker='>', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex, init=init)
plot_order('odeint_R_Hbr', color='b', marker='<', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex, init=init)

# %% [markdown]
# ## Example 2 (Quadratic function)
#
# \begin{equation}\label{eq:quad}
# f(X)=\frac{1}{2}X^T AX,\quad X \in \mathbb{R}^{500},\quad \lambda(A)\sim \mathcal{U}(10^{-3},1),
# \end{equation}
#
# where $A \in \mathbb{R}^{500 \times 500}$ is a positive--definite random matrix with eigenvalues
# uniformly distributed over the range $[10^{-3},1].$
#
# $x_0=(1,1,...,1)$

# %%
n = 100
seed=0
ex = exa.Example1(seed, n) 
plot_contourn(ex, xmin=-10, xmax=10, ymin=-10, ymax=10)

# %%
## Parameters
dt =1e-3
c = 2  # order
C = 1
steps =1000

# %%
# Initial conditions 
p0 = np.zeros(n)     # p0=(0,0,...,0)
x0 = np.ones(n)      # x0=(1,1,...,1)
x0_t = 0.01
p0_t = -HBr(ex, x0, p0, x0_t, c) 
init =[x0, x0_t, p0, p0_t]

# %%
## Euclidean Case
plt.figure(figsize=(10, 4))
plot_order('EB', color='c', marker='d', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex, init=init)
#plot_order('odeintE', color='m', marker='h', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex)
plot_order('HTVI_d', color='r', marker='<', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex, init=init)
plot_order('HTVI_adap', color='y', marker='H', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex, init=init)
plot_order('BS_d', color='b', marker='<', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex, init=init)
plot_order('RB_adap_new', color='r', marker='x', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)

# %%
## Relativistic Case
plt.figure(figsize=(10, 4))
plot_order('RB', color='k', marker='o', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex, init=init)
plot_order('RB_adap', color='green', marker='x', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex, init=init)
plot_order('odeint_R_Kbr', color='y', marker='>', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex, init=init)
plot_order('odeint_R_Hbr', color='b', marker='<', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex, init=init)
plot_order('RB_adap_new', color='r', marker='x', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)

plot_order('RB_new', color='magenta', marker='x', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex, init=init)

# %% [markdown]
# ## Example 3 (Quartic function 2)
#
# \begin{equation}
# f(X)=\sum_{i=1}^n i X_i^{4},  \quad n=50.
# \end{equation}
# This function is an example of a convex function that has a global minimum at $f(0)=0$, surrounded by a very flat region.
#
# $x_0=(2,2,...,2)$

# %%
n = 50 # dimension
ex = exa.Example7() 
plot_contourn(ex, xmin=-10, xmax=10, ymin=-10, ymax=10)

# %%
## Parameters
dt = 0.01
c = 5  # order
C = 1
steps =5000

# %%
# Initial conditions 
p0 = np.zeros(n)     # p0=(0,0,...,0)
x0 = 2*np.ones(n)    # x0=(2,2,...,2)
x0_t = 0.01
p0_t = -HBr(ex, x0, p0, x0_t, c) 
init =[x0, x0_t, p0, p0_t]

# %%
## Euclidean Case
plt.figure(figsize=(10, 4))
plot_order('EB', color='c', marker='d', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
#plot_order('odeintE', color='m', marker='h', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('HTVI_d', color='r', marker='<', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('HTVI_adap', color='y', marker='H', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('BS_d', color='b', marker='<', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)

# %%
## Relativistic Case
plt.figure(figsize=(10, 4))
plot_order('RB', color='k', marker='o', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('RB_adap', color='green', marker='x', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex, init=init)
plot_order('odeint_R_Kbr', color='y', marker='>', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('odeint_R_Hbr', color='b', marker='<', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('RB_adap_new', color='r', marker='x', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)

# %% [markdown]
# ### Example 4 (Camelback Function)
# We consider the nonconvex Camelback objective function,
#
# \begin{equation}\label{eq:camelback}
# f(X_1, X_2)=2X_1^2 - 1.05X_1^4 + \frac{1}{6}X_1^6 + X_1 X_2 + X_2^2.
# \end{equation}
#  A unique global minimum can be found at $f(0,0)=0$ while two local minima
# are located at $(X_{1}^{\pm},X_{2}^{\pm})\simeq\pm(-1.75,0.87)$ with $f(X_{1}^{\pm},X_{2}^{\pm})\simeq 0.3$.
#
# In this case $x_0=(1.8,-0.9)$

# %%
n = 2
x0 = np.array([1.8, -0.9]) 
ex = exa.Example3(x0) 
plot_contourn(ex, xmin=-2, xmax=2, ymin=-2, ymax=2)

# %%
## Parameters
dt = 0.001 
c = 2  # order
C = 1
steps =500

# %%
# Initial conditions 
p0 = np.zeros(n)             # p0=(0, 0)
x0 = np.array([1.8, -0.9])   # x0=(1.8, -0.9)
x0_t = 0.01
p0_t = -HBr(ex, x0, p0, x0_t, c) 
init =[x0, x0_t, p0, p0_t]

# %%
## Euclidean Case
plt.figure(figsize=(10, 4))
plot_order('EB', color='c', marker='d', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
#plot_order('odeintE', color='m', marker='h', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('HTVI_d', color='r', marker='<', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('HTVI_adap', color='y', marker='H', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('BS_d', color='b', marker='<', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)

# %%
## Relativistic Case
plt.figure(figsize=(10, 4))
plot_order('RB', color='k', marker='o', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('RB_adap', color='green', marker='x', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('odeint_R_Kbr', color='y', marker='>', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('odeint_R_Hbr', color='b', marker='<', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('RB_adap_new', color='r', marker='x', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)

# %% [markdown]
# ## Example 5 (Booth function)
# $$f(x, y) = (x+2 y-7)^{2}+(2 x+y-5)^{2}$$
# Global minimum at $f(1,3)=0 .$ We initialize at $x_{0}=(10,10)$. This function is usually evaluated on the region $-10 \leqslant x, y \leqslant 10 .$ All methods perform well on this problem which is not challenging.

# %%
n = 2
seed = 0
ex = exa.Example5(seed, n) 
plot_contourn(ex, xmin=-20, xmax=20, ymin=-20, ymax=20)

# %%
## Parameters
dt = 0.01 
c = 5 # order
C = 1
steps =100

# %%
# Initial conditions 
p0 = np.zeros(n)     # p0=(0,0)
x0 = np.array([10,10])    # x0=(2,2,...,2)
x0_t = 0.01
p0_t = -HBr(ex, x0, p0, x0_t, c) 
init =[x0, x0_t, p0, p0_t]

# %%
## Euclidean Case
plt.figure(figsize=(10, 4))
plot_order('EB', color='c', marker='d', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('odeintE', color='m', marker='h', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('HTVI_d', color='r', marker='<', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('HTVI_adap', color='y', marker='H', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('BS_d', color='b', marker='<', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
# Out:
# /Users/marialuisa/Dropbox/HMC/Breg_codes/notebook examples/integrators.py:94: RuntimeWarning: overflow encountered in double_scalars
#   + (-2*c**3 + c * cdot) / (cdot * (q0_t)**(cdot / c + 1 - 2 * c)) * dt * C * example.f(q0)
# /Users/marialuisa/Dropbox/HMC/Breg_codes/notebook examples/integrators.py:93: RuntimeWarning: invalid value encountered in double_scalars
#   p1_t2 = (c**3 + c * cdot) / (2 * cdot * (q0_t)**(c + cdot / c + 1)) * dt * np.dot(p1, p1) \
# /Users/marialuisa/Dropbox/HMC/Breg_codes/notebook examples/examples.py:129: RuntimeWarning: overflow encountered in double_scalars
#   return (x[0] + 2 * x[1] - 7) ** 2 + (2 * x[0] + x[1] - 5) ** 2
# /Users/marialuisa/Dropbox/HMC/Breg_codes/notebook examples/integrators.py:91: RuntimeWarning: overflow encountered in multiply
#   p1 = p0 - (c**2/cdot) * dt * C * (q0_t) ** (2*c - cdot/c) * example.gradf(q0)
# /Users/marialuisa/Dropbox/HMC/Breg_codes/notebook examples/integrators.py:91: RuntimeWarning: invalid value encountered in subtract
#   p1 = p0 - (c**2/cdot) * dt * C * (q0_t) ** (2*c - cdot/c) * example.gradf(q0)
# /Users/marialuisa/opt/anaconda3/lib/python3.8/site-packages/numpy/ma/core.py:6849: RuntimeWarning: overflow encountered in power
#   result = np.where(m, fa, umath.power(fa, fb)).view(basetype)

# %%
## Relativistic Case
plt.figure(figsize=(10, 4))
plot_order('RB', color='k', marker='o', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('RB_adap', color='green', marker='x', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('odeint_R_Kbr', color='y', marker='>', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('odeint_R_Hbr', color='b', marker='<', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('RB_adap_new', color='r', marker='x', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)

# %% [markdown]
# ## Example 6 (Schwefel function)
# $$f(x) \equiv \sum_{i=1}^{n} x_{i}^{10} .$$
# The minimum is at $f(0)=0$. The function is usually considered over $-10 \leqslant x_{i} \leqslant 10$. This function grows even stronger than the previous two cases. We consider $n=20$ dimensions and initialize at $x_{0}=(2, \ldots, 2) .$ Note that $\delta>0$ is essential to control the kinetic energy and improve convergence.

# %%
n = 20
seed = 0
ex = exa.Example8(n) 
plot_contourn(ex, xmin=-10, xmax=10, ymin=-10, ymax=10)

# %%
# Params
dt = 0.1 
c = 2   # order
C = 1
steps =5000

# %%
# Initial conditions 
p0 = np.zeros(n)     # p0=(0,0)
x0 = 2*np.ones(n)    # x0=(2,2,...,2)
x0_t = 0.01
p0_t = -HBr(ex, x0, p0, x0_t, c) 
init =[x0, x0_t, p0, p0_t]

# %%
## Euclidean Case
plt.figure(figsize=(10, 4))
plot_order('EB', color='c', marker='d', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('odeintE', color='m', marker='h', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('HTVI_d', color='r', marker='<', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('HTVI_adap', color='y', marker='H', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('BS_d', color='b', marker='<', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
# Out:
# /Users/marialuisa/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/odepack.py:247: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# /Users/marialuisa/Dropbox/HMC/Breg_codes/notebook examples/examples.py:188: RuntimeWarning: overflow encountered in power
#   return np.sum(x ** 10)
# /Users/marialuisa/Dropbox/HMC/Breg_codes/notebook examples/examples.py:188: RuntimeWarning: invalid value encountered in power
#   return np.sum(x ** 10)
# /Users/marialuisa/Dropbox/HMC/Breg_codes/notebook examples/examples.py:191: RuntimeWarning: overflow encountered in power
#   gradV = 10 * (x ** 9)
# /Users/marialuisa/Dropbox/HMC/Breg_codes/notebook examples/examples.py:188: RuntimeWarning: overflow encountered in power
#   return np.sum(x ** 10)
# /Users/marialuisa/Dropbox/HMC/Breg_codes/notebook examples/integrators.py:64: RuntimeWarning: invalid value encountered in double_scalars
#   p1_t = p0_t + dt * c * (c+1)/(2 * (q0_t) ** (c+2)) * np.dot(p1, p1) \
# /Users/marialuisa/Dropbox/HMC/Breg_codes/notebook examples/integrators.py:63: RuntimeWarning: invalid value encountered in subtract
#   p1 = p0 - c * dt * C * (q0_t) ** (2*c-1) * example.gradf(q0)
# /Users/marialuisa/Dropbox/HMC/Breg_codes/notebook examples/examples.py:191: RuntimeWarning: overflow encountered in power
#   gradV = 10 * (x ** 9)
# /Users/marialuisa/Dropbox/HMC/Breg_codes/notebook examples/examples.py:188: RuntimeWarning: overflow encountered in power
#   return np.sum(x ** 10)
# /Users/marialuisa/Dropbox/HMC/Breg_codes/notebook examples/integrators.py:93: RuntimeWarning: invalid value encountered in double_scalars
#   p1_t2 = (c**3 + c * cdot) / (2 * cdot * (q0_t)**(c + cdot / c + 1)) * dt * np.dot(p1, p1) \
# /Users/marialuisa/Dropbox/HMC/Breg_codes/notebook examples/integrators.py:91: RuntimeWarning: invalid value encountered in subtract
#   p1 = p0 - (c**2/cdot) * dt * C * (q0_t) ** (2*c - cdot/c) * example.gradf(q0)
# /Users/marialuisa/Dropbox/HMC/Breg_codes/notebook examples/examples.py:191: RuntimeWarning: overflow encountered in power
#   gradV = 10 * (x ** 9)
# /Users/marialuisa/Dropbox/HMC/Breg_codes/notebook examples/examples.py:188: RuntimeWarning: overflow encountered in power
#   return np.sum(x ** 10)
# /Users/marialuisa/Dropbox/HMC/Breg_codes/notebook examples/integrators.py:131: RuntimeWarning: invalid value encountered in double_scalars
#   p1_t = p1_t + dt / 2 * c * (c + 1) / (2 * tt ** (c + 2)) * np.dot(p, p) \
# /Users/marialuisa/Dropbox/HMC/Breg_codes/notebook examples/integrators.py:129: RuntimeWarning: invalid value encountered in subtract
#   p = p - dt / 2 * C * c * tt ** (2 * c - 1) * example.gradf(q)
# /Users/marialuisa/opt/anaconda3/lib/python3.8/site-packages/matplotlib/ticker.py:2526: RuntimeWarning: overflow encountered in power
#   ticklocs = b ** decades
# /Users/marialuisa/opt/anaconda3/lib/python3.8/site-packages/matplotlib/ticker.py:2369: RuntimeWarning: invalid value encountered in double_scalars
#   return abs(x - np.round(x)) < atol
# /Users/marialuisa/opt/anaconda3/lib/python3.8/site-packages/matplotlib/ticker.py:1179: RuntimeWarning: invalid value encountered in double_scalars
#   coeff = round(x / b ** exponent)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2191                            else suppress())
#    2192                     with ctx:
# -> 2193                         self.figure.draw(renderer)
#    2194
#    2195                     bbox_inches = self.figure.get_tightbbox(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1861
#    1862             self.patch.draw(renderer)
# -> 1863             mimage._draw_list_compositing_images(
#    1864                 renderer, self, artists, self.suppressComposite)
#    1865
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2745             renderer.stop_rasterizing()
#    2746
# -> 2747         mimage._draw_list_compositing_images(renderer, self, artists)
#    2748
#    2749         renderer.close_group('axes')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1162         renderer.open_group(__name__, gid=self.get_gid())
#    1163
# -> 1164         ticks_to_draw = self._update_ticks()
#    1165         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1166                                                                 renderer)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axis.py in _update_ticks(self)
#    1020         """
#    1021         major_locs = self.get_majorticklocs()
# -> 1022         major_labels = self.major.formatter.format_ticks(major_locs)
#    1023         major_ticks = self.get_major_ticks(len(major_locs))
#    1024         self.major.formatter.set_locs(major_locs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/ticker.py in format_ticks(self, values)
#     248         """Return the tick labels for all the ticks at once."""
#     249         self.set_locs(values)
# --> 250         return [self(value, i) for i, value in enumerate(values)]
#     251
#     252     def format_data(self, value):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/ticker.py in <listcomp>(.0)
#     248         """Return the tick labels for all the ticks at once."""
#     249         self.set_locs(values)
# --> 250         return [self(value, i) for i, value in enumerate(values)]
#     251
#     252     def format_data(self, value):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/ticker.py in __call__(self, x, pos)
#    1177         is_x_decade = is_close_to_int(fx)
#    1178         exponent = round(fx) if is_x_decade else np.floor(fx)
# -> 1179         coeff = round(x / b ** exponent)
#    1180         if is_x_decade:
#    1181             fx = round(fx)
#
# ValueError: cannot convert float NaN to integer

# %%
## Relativistic Case
plt.figure(figsize=(10, 4))
plot_order('RB', color='k', marker='o', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('RB_adap', color='green', marker='x', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('odeint_R_Kbr', color='y', marker='>', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('odeint_R_Hbr', color='b', marker='<', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
# Out:
# /Users/marialuisa/Dropbox/HMC/Breg_codes/notebook examples/plot_ex.py:59: RuntimeWarning: divide by zero encountered in log10
#   order = np.log10(fsol[-1]) / np.log10(steps-1)
# /Users/marialuisa/opt/anaconda3/lib/python3.8/site-packages/matplotlib/ticker.py:1179: RuntimeWarning: divide by zero encountered in double_scalars
#   coeff = round(x / b ** exponent)
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2191                            else suppress())
#    2192                     with ctx:
# -> 2193                         self.figure.draw(renderer)
#    2194
#    2195                     bbox_inches = self.figure.get_tightbbox(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1861
#    1862             self.patch.draw(renderer)
# -> 1863             mimage._draw_list_compositing_images(
#    1864                 renderer, self, artists, self.suppressComposite)
#    1865
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2745             renderer.stop_rasterizing()
#    2746
# -> 2747         mimage._draw_list_compositing_images(renderer, self, artists)
#    2748
#    2749         renderer.close_group('axes')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1162         renderer.open_group(__name__, gid=self.get_gid())
#    1163
# -> 1164         ticks_to_draw = self._update_ticks()
#    1165         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1166                                                                 renderer)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axis.py in _update_ticks(self)
#    1020         """
#    1021         major_locs = self.get_majorticklocs()
# -> 1022         major_labels = self.major.formatter.format_ticks(major_locs)
#    1023         major_ticks = self.get_major_ticks(len(major_locs))
#    1024         self.major.formatter.set_locs(major_locs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/ticker.py in format_ticks(self, values)
#     248         """Return the tick labels for all the ticks at once."""
#     249         self.set_locs(values)
# --> 250         return [self(value, i) for i, value in enumerate(values)]
#     251
#     252     def format_data(self, value):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/ticker.py in <listcomp>(.0)
#     248         """Return the tick labels for all the ticks at once."""
#     249         self.set_locs(values)
# --> 250         return [self(value, i) for i, value in enumerate(values)]
#     251
#     252     def format_data(self, value):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/ticker.py in __call__(self, x, pos)
#    1177         is_x_decade = is_close_to_int(fx)
#    1178         exponent = round(fx) if is_x_decade else np.floor(fx)
# -> 1179         coeff = round(x / b ** exponent)
#    1180         if is_x_decade:
#    1181             fx = round(fx)
#
# OverflowError: cannot convert float infinity to integer

# %% [markdown]
# ## Example 7(Correlated quadratic function)
# Let us consider the correlated quadratic function
# $$
# f(X)=\frac{1}{2} X^{T} A X, \quad A_{i j}=\frac{\sqrt{i j}}{2^{|i-j|}} \quad \text { for } \quad i, j=1, \ldots, 50
# $$
# The initial position in each is sampled uniformly at random in the range $-1 \leq X_{0, i} \leq 1$.

# %%
n = 50
seed = 0
ex = exa.Example2(n) 
plot_contourn(ex, xmin=-10, xmax=10, ymin=-10, ymax=10)

# %%
# Params
dt = 0.0001 
c = 2   # order
C = 1
steps =300

# %%
# Initial conditions 
np.random.seed(0)
p0 = np.zeros(n)     # p0=(0,0)
x0 = np.random.uniform(-1, 1,n)
x0_t = 0.01
p0_t = -HBr(ex, x0, p0, x0_t, c) 
init =[x0, x0_t, p0, p0_t]

# %%
## Euclidean Case
plt.figure(figsize=(10, 4))
plot_order('EB', color='c', marker='d', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('odeintE', color='m', marker='h', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('HTVI_d', color='r', marker='<', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('HTVI_adap', color='y', marker='H', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('BS_d', color='b', marker='<', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)

# %%
## Relativistic Case
plt.figure(figsize=(10, 4))
plot_order('RB', color='k', marker='o', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('RB_adap', color='green', marker='x', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('odeint_R_Kbr', color='y', marker='>', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('odeint_R_Hbr', color='b', marker='<', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('RB_adap_new', color='r', marker='x', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)

# %% [markdown]
# ## Example 8 (Matyas function)
# Matyas function:
# $$f(x, y) \equiv 0.26\left(x^{2}+y^{2}\right)-0.48 x y .$$
# Global minimum is at $f(0,0)=0 .$ We initialize at $x_{0}=(10,-7)$. This function is usually evaluated on the region $-10 \leqslant x, y \leqslant 10$.

# %%
ex = exa.Example9() 
plot_contourn(ex, xmin=-10, xmax=10, ymin=-10, ymax=10)

# %%
# Params
dt = 0.01 
c = 4   # order
C = 1
steps =300

# %%
# Initial conditions 
n=2
x0 = np.array([10, -7])
p0 = np.zeros(n)     # p0=(0,0)
x0_t = 0.01
p0_t = -HBr(ex, x0, p0, x0_t, c) 
init =[x0, x0_t, p0, p0_t]

# %%
## Euclidean Case
plt.figure(figsize=(10, 4))
plot_order('EB', color='c', marker='d', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('odeintE', color='m', marker='h', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('HTVI_d', color='r', marker='<', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('HTVI_adap', color='y', marker='H', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('BS_d', color='b', marker='<', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
# Out:
# /Users/marialuisa/Dropbox/HMC/Breg_codes/notebook examples/integrators.py:94: RuntimeWarning: overflow encountered in double_scalars
#   + (-2*c**3 + c * cdot) / (cdot * (q0_t)**(cdot / c + 1 - 2 * c)) * dt * C * example.f(q0)
# /Users/marialuisa/Dropbox/HMC/Breg_codes/notebook examples/integrators.py:93: RuntimeWarning: invalid value encountered in double_scalars
#   p1_t2 = (c**3 + c * cdot) / (2 * cdot * (q0_t)**(c + cdot / c + 1)) * dt * np.dot(p1, p1) \
# /Users/marialuisa/Dropbox/HMC/Breg_codes/notebook examples/examples.py:208: RuntimeWarning: overflow encountered in double_scalars
#   return 0.26 * (x[0]**2 + x[1]**2) - 0.48 * x[0] * x[1]
# /Users/marialuisa/Dropbox/HMC/Breg_codes/notebook examples/integrators.py:91: RuntimeWarning: overflow encountered in multiply
#   p1 = p0 - (c**2/cdot) * dt * C * (q0_t) ** (2*c - cdot/c) * example.gradf(q0)
# /Users/marialuisa/Dropbox/HMC/Breg_codes/notebook examples/integrators.py:91: RuntimeWarning: invalid value encountered in subtract
#   p1 = p0 - (c**2/cdot) * dt * C * (q0_t) ** (2*c - cdot/c) * example.gradf(q0)
# /Users/marialuisa/opt/anaconda3/lib/python3.8/site-packages/numpy/ma/core.py:6849: RuntimeWarning: overflow encountered in power
#   result = np.where(m, fa, umath.power(fa, fb)).view(basetype)

# %%
## Relativistic Case
plt.figure(figsize=(10, 4))
plot_order('RB', color='k', marker='o', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('RB_adap', color='green', marker='x', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('odeint_R_Kbr', color='y', marker='>', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('odeint_R_Hbr', color='b', marker='<', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)

plot_order('RB_adap_new', color='r', marker='x', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)

# %% [markdown]
# ## Example 9 (Lévi function)
# Lévi function #13: $f(x, y) \equiv \sin ^{2} 3 \pi x+(x-1)^{2}\left(1+\sin ^{2} 3 \pi y\right)+(y-$ 1) $^{2}\left(1+\sin ^{2} 2 \pi y\right)$. This function is multimodal, with the global minimum at $f(1,1)=0 .$ We initialize at $x_{0}=(10,-10)$. This function is usually studied on the region $-10 \leqslant x, y \leqslant 10$. Although this function is nonconvex, the optimization problem is not very challenging.

# %%
ex = exa.Example10() 
plot_contourn(ex, xmin=-10, xmax=10, ymin=-10, ymax=10)

# %%
# Params
dt = 0.001 
c = 2 # order
C = 1
steps =300

# %%
# Initial conditions 
n=2
x0 = np.array([10, -10])
p0 = np.zeros(n)     # p0=(0,0)
x0_t = 0.01
p0_t = -HBr(ex, x0, p0, x0_t, c) 
init =[x0, x0_t, p0, p0_t]

# %%
## Euclidean Case
plt.figure(figsize=(10, 4))
plot_order('EB', color='c', marker='d', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('odeintE', color='m', marker='h', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('HTVI_d', color='r', marker='<', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('HTVI_adap', color='y', marker='H', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('BS_d', color='b', marker='<', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
# Out:
# /Users/marialuisa/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/odepack.py:247: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# /Users/marialuisa/Dropbox/HMC/Breg_codes/notebook examples/examples.py:227: RuntimeWarning: overflow encountered in double_scalars
#   return np.sin(3*np.pi*x[0])**2 + (x[0]-1)**2 * (1 + np.sin(3 * np.pi * x[1])**2) +\
# /Users/marialuisa/Dropbox/HMC/Breg_codes/notebook examples/examples.py:228: RuntimeWarning: overflow encountered in double_scalars
#   (x[1]-1)**2 * (1 + np.sin(2 * np.pi * x[1])**2)
# /Users/marialuisa/Dropbox/HMC/Breg_codes/notebook examples/examples.py:227: RuntimeWarning: invalid value encountered in sin
#   return np.sin(3*np.pi*x[0])**2 + (x[0]-1)**2 * (1 + np.sin(3 * np.pi * x[1])**2) +\
# /Users/marialuisa/opt/anaconda3/lib/python3.8/site-packages/numpy/ma/core.py:6849: RuntimeWarning: overflow encountered in power
#   result = np.where(m, fa, umath.power(fa, fb)).view(basetype)

# %%
## Relativistic Case
plt.figure(figsize=(10, 4))
plot_order('RB', color='k', marker='o', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('RB_adap', color='green', marker='x', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('RB_adap_new', color='r', marker='x', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)

#plot_order('odeint_R_Kbr', color='y', marker='>', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
#plot_order('odeint_R_Hbr', color='b', marker='<', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)

# %% [markdown]
# ## Example 10 (Sum of squares)
# $$f(x) \equiv \sum_{i=1}^{n} i x_{i}^{2} .$$
# The minimum is at $f(0)=0 .$ We consider $n=100$ dimensions and initialize at $x_{0}=(10, \ldots, 10) .$ The usual region of study is $-10 \leqslant x_{i} \leqslant 10 .$

# %%
ex = exa.Example11() 
plot_contourn(ex, xmin=-10, xmax=10, ymin=-10, ymax=10)

# %%
# Params
dt = 0.001 
c = 2   # order
C = 1
steps =300

# %%
n=100
x0 = 10 * np.ones(n)
p0 = np.zeros(n)     # p0=(0,0)
x0_t = 0.01
p0_t = -HBr(ex, x0, p0, x0_t, c) 
init =[x0, x0_t, p0, p0_t]

# %%
## Euclidean Case
plt.figure(figsize=(10, 4))
plot_order('EB', color='c', marker='d', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('odeintE', color='m', marker='h', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('HTVI_d', color='r', marker='<', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('HTVI_adap', color='y', marker='H', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('BS_d', color='b', marker='<', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)

# %%
## Relativistic Case
plt.figure(figsize=(10, 4))
plot_order('RB', color='k', marker='o', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('RB_adap', color='green', marker='x', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('odeint_R_Kbr', color='y', marker='>', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('odeint_R_Hbr', color='b', marker='<', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('RB_adap_new', color='r', marker='x', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
# Out:
# /Users/marialuisa/Dropbox/HMC/Breg_codes/notebook examples/integratorFJ.py:42: RuntimeWarning: invalid value encountered in sqrt
#   sq = np.sqrt(1 - np.sum(x ** 2) / v ** 2)
# /Users/marialuisa/Dropbox/HMC/Breg_codes/notebook examples/integratorFJ.py:25: RuntimeWarning: invalid value encountered in sqrt
#   sq = np.sqrt(1 - np.sum(x ** 2) / v ** 2)
# /Users/marialuisa/Dropbox/HMC/Breg_codes/notebook examples/integratorFJ.py:35: RuntimeWarning: invalid value encountered in sqrt
#   arg3 = v ** 3 * m * x / np.sqrt(v ** 2 - np.sum(x ** 2))**3

# %% [markdown]
# ## Example 11 (Beale function)
# $f(x, y) \equiv(1.5-x+x y)^{2}+\left(2.25-x+x y^{2}\right)^{2}+(2.625$ $\left.-x+x y^{3}\right)^{2} .$ The global minimum is at $f(3,1 / 2)=0$, lying on a flat and narrow valley which makes optimization challenging. Note also that this functions grows stronger than a quadratic. This function is usually considered on the region $-4.5 \leqslant$ $x, y \leqslant 4.5 .$ We initialize at $x_{0}=(-3,-3) .$

# %%
ex = exa.Example12() 
plot_contourn(ex, xmin=-4.5, xmax=4.5, ymin=-4.5, ymax=4.5)

# %%
# Params
dt = 0.000001 
c = 2  # order
C = 1
steps =500

# %%
n=2
x0 = np.array([-3,-3])
p0 = np.zeros(n)     # p0=(0,0)
x0_t = 0.01
p0_t = -HBr(ex, x0, p0, x0_t, c) 
init =[x0, x0_t, p0, p0_t]

# %%
## Euclidean Case
plt.figure(figsize=(10, 4))
plot_order('EB', color='c', marker='d', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('odeintE', color='m', marker='h', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('HTVI_d', color='r', marker='<', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('HTVI_adap', color='y', marker='H', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('BS_d', color='b', marker='<', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
# Out:
# /Users/marialuisa/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/odepack.py:247: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# /Users/marialuisa/Dropbox/HMC/Breg_codes/notebook examples/examples.py:278: RuntimeWarning: overflow encountered in double_scalars
#   return (1.5-x[0] + x[0]*x[1])**2 + (2.25-x[0] + x[0] * x[1]**2)**2 + (2.625 - x[0] + x[0]*x[1]**3)**2
# /Users/marialuisa/opt/anaconda3/lib/python3.8/site-packages/numpy/ma/core.py:6849: RuntimeWarning: overflow encountered in power
#   result = np.where(m, fa, umath.power(fa, fb)).view(basetype)

# %%
## Relativistic Case
plt.figure(figsize=(10, 4))
plot_order('RB', color='k', marker='o', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('RB_adap', color='green', marker='x', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('odeint_R_Kbr', color='y', marker='>', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('odeint_R_Hbr', color='b', marker='<', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('RB_adap_new', color='r', marker='x', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)

# %% [markdown]
# ## Example 12(Chung-Reynolds function)
# $$f(x) \equiv\left(\sum_{i=1}^{n} x_{i}^{2}\right)^{2}.$$ The global minimum is at $f(0)=0 .$ This function is usually considered on the region $-100 \leqslant x_{i} \leqslant 100 .$ We consider $n=50$ dimensions and initialize at $x_{0}=(50, \ldots, 50)$.

# %%
ex = exa.Example13() 
plot_contourn(ex, xmin=-100, xmax=100, ymin=-100, ymax=100)

# %%
# Params
dt = 0.1 
c = 2  # order
C = 1
steps =500

# %%
n=50
x0 = 50*np.ones(n)
p0 = np.zeros(n)     # p0=(0,0)
x0_t = 0.01
p0_t = -HBr(ex, x0, p0, x0_t, c) 
init =[x0, x0_t, p0, p0_t]

# %%
## Euclidean Case
plt.figure(figsize=(10, 4))
plot_order('EB', color='c', marker='d', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('odeintE', color='m', marker='h', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('HTVI_d', color='r', marker='<', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('HTVI_adap', color='y', marker='H', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('BS_d', color='b', marker='<', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)

# %%
## Relativistic Case
plt.figure(figsize=(10, 4))
plot_order('RB', color='k', marker='o', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('RB_adap', color='green', marker='x', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('odeint_R_Kbr', color='y', marker='>', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('odeint_R_Hbr', color='b', marker='<', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)

# %% [markdown]
# ## Example 14(Zakharov function)
# $f(x) \equiv \sum_{i=1}^{n} x_{i}^{2}+\left(\frac{1}{2} \sum_{i=1}^{n} i x_{i}\right)^{2}+\left(\frac{1}{2} \sum_{i=1}^{n} i x_{i}\right)^{4}$ The minimum is at $f(0)=0 .$ The region of interest is usually $-5 \leqslant x_{i} \leqslant 10$. We consider $n=5$ and initialize at $x_{0}=(1, \ldots, 1) $.

# %%
ex = exa.Example14() 
plot_contourn(ex, xmin=-5, xmax=10, ymin=-5, ymax=10)

# %%
# Params
dt = 0.00001 
c = 2  # order
C = 1
steps =500

# %%
n=5
x0 = np.ones(n)
p0 = np.zeros(n)     # p0=(0,0)
x0_t = 0.01
p0_t = -HBr(ex, x0, p0, x0_t, c) 
init =[x0, x0_t, p0, p0_t]

# %%
## Euclidean Case
plt.figure(figsize=(10, 4))
plot_order('EB', color='c', marker='d', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('odeintE', color='m', marker='h', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('HTVI_d', color='r', marker='<', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('HTVI_adap', color='y', marker='H', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('BS_d', color='b', marker='<', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)

# %%
## Relativistic Case
plt.figure(figsize=(10, 4))
plot_order('RB', color='k', marker='o', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('RB_adap', color='green', marker='x', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('odeint_R_Kbr', color='y', marker='>', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('odeint_R_Hbr', color='b', marker='<', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)

# %% [markdown]
# ## Example 15(Qing function)
# $f(x) \equiv \sum_{i=1}^{n}\left(x_{i}^{2}-i\right)^{2}$. This function is multimodal, with minimum at $x_{i}^{\star}=\pm \sqrt{i}, f\left(x^{\star}\right)=0 .$ The function is usually studied in the region $-500 \leqslant x_{i} \leqslant 500 .$ We consider $n=100$ dimensions with initialization at $x_{0}=(50, \ldots, 50)$

# %%
ex = exa.Example15() 
plot_contourn(ex, xmin=-500, xmax=500, ymin=-500, ymax=500)

# %%
# Params
dt = 0.01 
c = 2  # order
C = 1
steps =500

# %%
n=100
x0 = np.ones(n)
p0 = np.zeros(n)     # p0=(0,0)
x0_t = 0.01
p0_t = -HBr(ex, x0, p0, x0_t, c) 
init =[x0, x0_t, p0, p0_t]

# %%
## Euclidean Case
plt.figure(figsize=(10, 4))
plot_order('EB', color='c', marker='d', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('odeintE', color='m', marker='h', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('HTVI_d', color='r', marker='<', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('HTVI_adap', color='y', marker='H', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('BS_d', color='b', marker='<', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)

# %%
## Relativistic Case
plt.figure(figsize=(10, 4))
plot_order('RB', color='k', marker='o', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('RB_adap', color='green', marker='x', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('odeint_R_Kbr', color='y', marker='>', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('odeint_R_Hbr', color='b', marker='<', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)

# %% [markdown]
# ## Example 16(Three-hump camel back function)
# $f(x, y) \equiv 2 x^{2}-1.05 x^{4}+x^{6} / 6+$ $x y+y^{2}$.
# This is a multimodal function with global minimum is at $f(0,0)=0$. The region of interest is usually $-5 \leqslant x, y \leqslant 5 .$ We initialize at $x_{0}=(5,5) .$ The two local minima are somewhat close to the global minimum which makes optimization challenging.

# %%
ex = exa.Example16() 
plot_contourn(ex, xmin=-5, xmax=5, ymin=-5, ymax=5)

# %%
# Params
dt = 0.001 
c = 2  # order
C = 1
steps =500

# %%
n=2
x0 = np.array([5,5])
p0 = np.zeros(n)     # p0=(0,0)
x0_t = 0.01
p0_t = -HBr(ex, x0, p0, x0_t, c) 
init =[x0, x0_t, p0, p0_t]

# %%
## Euclidean Case
plt.figure(figsize=(10, 4))
plot_order('EB', color='c', marker='d', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('odeintE', color='m', marker='h', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('HTVI_d', color='r', marker='<', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('HTVI_adap', color='y', marker='H', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('BS_d', color='b', marker='<', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)

# %%
## Relativistic Case
plt.figure(figsize=(10, 4))
plot_order('RB', color='k', marker='o', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('RB_adap', color='green', marker='x', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('odeint_R_Kbr', color='y', marker='>', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
plot_order('odeint_R_Hbr', color='b', marker='<', dt=dt, c=c, C=C, steps=steps, n=n,ex=ex,init=init)
